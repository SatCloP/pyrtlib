# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SatCloP/pyrtlib/blob/main/docs/source/notebook/first_run.ipynb)

# %% [markdown]
# # My first test with PyRTlib

# %% [markdown]
# Installing PyRTlib via pip. Note that the following command will also install all requirements to execute properly PyRTlib package. It is possible to test development version by installing the package directly from github repository.
# ```console
# !pip install https://github.com/SatCloP/pyrtlib/archive/refs/heads/dev.zip
# ```

# %%
# !pip install pyrtlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyrtlib
#   Downloading pyrtlib-1.1.1-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from pyrtlib) (68.1.2)
# Requirement already satisfied: pandas in /home/runner/.local/lib/python3.12/site-packages (from pyrtlib) (3.0.1)
# Requirement already satisfied: numpy in /home/runner/.local/lib/python3.12/site-packages (from pyrtlib) (2.4.3)
# Requirement already satisfied: scipy in /home/runner/.local/lib/python3.12/site-packages (from pyrtlib) (1.17.1)
# Requirement already satisfied: scikit-learn in /home/runner/.local/lib/python3.12/site-packages (from pyrtlib) (1.8.0)
# Requirement already satisfied: netCDF4 in /home/runner/.local/lib/python3.12/site-packages (from pyrtlib) (1.7.4)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from pyrtlib) (2.31.0)
# Collecting bs4 (from pyrtlib)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: matplotlib in /home/runner/.local/lib/python3.12/site-packages (from pyrtlib) (3.10.8)
# Requirement already satisfied: beautifulsoup4 in /home/runner/.local/lib/python3.12/site-packages (from bs4->pyrtlib) (4.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/runner/.local/lib/python3.12/site-packages (from matplotlib->pyrtlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/runner/.local/lib/python3.12/site-packages (from matplotlib->pyrtlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/runner/.local/lib/python3.12/site-packages (from matplotlib->pyrtlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/runner/.local/lib/python3.12/site-packages (from matplotlib->pyrtlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib->pyrtlib) (24.0)
# Requirement already satisfied: pillow>=8 in /home/runner/.local/lib/python3.12/site-packages (from matplotlib->pyrtlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /usr/lib/python3/dist-packages (from matplotlib->pyrtlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3/dist-packages (from matplotlib->pyrtlib) (2.8.2)
# Requirement already satisfied: cftime in /home/runner/.local/lib/python3.12/site-packages (from netCDF4->pyrtlib) (1.6.5)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from netCDF4->pyrtlib) (2023.11.17)
# Requirement already satisfied: joblib>=1.3.0 in /home/runner/.local/lib/python3.12/site-packages (from scikit-learn->pyrtlib) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/runner/.local/lib/python3.12/site-packages (from scikit-learn->pyrtlib) (3.6.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/runner/.local/lib/python3.12/site-packages (from beautifulsoup4->bs4->pyrtlib) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/lib/python3/dist-packages (from beautifulsoup4->bs4->pyrtlib) (4.10.0)
# Downloading pyrtlib-1.1.1-py3-none-any.whl (251 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 251.7/251.7 kB 19.4 MB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4, pyrtlib
# Successfully installed bs4-0.0.2 pyrtlib-1.1.1

# %% [markdown]
# Import necessary packages to perform and plotting your first spectrum in PyRTlib.

# %%
# This requires jupyter-matplotlib a.k.a. ipympl.
# ipympl can be install via pip or conda.
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 15})
import numpy as np

# %% [markdown]
# Load standard climnatology and utils functions necessary to run the code.

# %%
from pyrtlib.absorption_model import O2AbsModel
from pyrtlib.climatology import AtmosphericProfiles as atmp
from pyrtlib.tb_spectrum import TbCloudRTE
from pyrtlib.utils import ppmv2gkg, mr2rh

# %% [markdown]
# The following code allows to performing spectra for one typical climatologies (Tropical) at 90° elevation angles. Please refer to the PyRTlib documentation for more details on how to use the library.

# %%
z, p, _, t, md = atmp.gl_atm(atmp.TROPICAL)

gkg = ppmv2gkg(md[:, atmp.H2O], atmp.H2O)
rh = mr2rh(p, t, gkg)[0] / 100

frq = np.arange(20, 1001, 1)

rte = TbCloudRTE(z, p, t, rh, frq)
rte.init_absmdl('R22SD')
O2AbsModel.model = 'R22'
O2AbsModel.set_ll()
df = rte.execute()
df = df.set_index(frq)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 12
#      10 O2AbsModel.model = 'R22'
#      11 O2AbsModel.set_ll()
# ---> 12 df = rte.execute()
#      13 df = df.set_index(frq)
#
# File ~/.local/lib/python3.12/site-packages/pyrtlib/tb_spectrum.py:350, in TbCloudRTE.execute(self, only_bt)
#     348 RTEquation._emissivity = self._es[j]
#     349 # Rosenkranz, personal communication, 2019/02/12 (email)
# --> 350 self.awet[j, k, :], self.adry[j, k, :] = RTEquation.clearsky_absorption(self.p, self.tk, e, self.frq[j],
#     351                                             self.o3n, self.amu if self._uncertainty else None)
#     352 self.sptauwet[j, k], \
#     353     self.ptauwet[j, k, :] = RTEquation.exponential_integration(
#     354         True, self.awet[j, k, :], ds, 1, self.nl, 1)
#     355 self.sptaudry[j, k], \
#     356     self.ptaudry[j, k, :] = RTEquation.exponential_integration(
#     357         True, self.adry[j, k, :], ds, 1, self.nl, 1)
#
# File ~/.local/lib/python3.12/site-packages/pyrtlib/rt_equation.py:551, in RTEquation.clearsky_absorption(p, t, e, frq, o3n, amu)
#     549 pdrykpa = p[i] / 10.0 - ekpa
#     550 # add H2O term
# --> 551 npp, ncpp = H2OAbsModel().h2o_absorption(pdrykpa, v, ekpa, frq, amu)
#     552 awet[i] = factor * (npp + ncpp) * db2np
#     553 # add O2 term
#
# File ~/.local/lib/python3.12/site-packages/pyrtlib/absorption_model.py:572, in H2OAbsModel.h2o_absorption(self, pdrykpa, vx, ekpa, frq, amu)
#     569 for j in range(0, 2):
#     570     if width2 > 0 and j == 0 and np.abs(df[j]) < (10 * width0):
#     571         # speed-dependent resonant shape factor, minus base
# --> 572         xc = complex(
#     573             (width0 - np.dot(1.5, width2)), df[j]) / width2
#     574         if H2OAbsModel.model == 'R20SD':
#     575             if i == 1:
#
# TypeError: only 0-dimensional arrays can be converted to Python scalars

# %% [markdown]
# Plotting zenith upwelling brigthness temperature.

# %%
df.tbtotal.plot(figsize=(25, 8), linewidth=3, xlabel="Frequency [GHz]", ylabel="Brightness Temperature [K]", grid=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.tbtotal.plot(figsize=(25, 8), linewidth=3, xlabel="Frequency [GHz]", ylabel="Brightness Temperature [K]", grid=True)
#
# NameError: name 'df' is not defined
